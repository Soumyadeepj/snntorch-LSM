# %%
# !pip install snntorch
# !pip install tonic
# Out:
# Requirement already satisfied: snntorch in c:\users\soumy\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: nirtorch in c:\users\soumy\anaconda3\lib\site-packages (from snntorch) (0.2.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\soumy\anaconda3\lib\site-packages (from snntorch) (1.21.6)
# Requirement already satisfied: pandas in c:\users\soumy\anaconda3\lib\site-packages (from snntorch) (1.4.4)
# Requirement already satisfied: nir in c:\users\soumy\anaconda3\lib\site-packages (from snntorch) (0.2.0)
# Requirement already satisfied: matplotlib in c:\users\soumy\anaconda3\lib\site-packages (from snntorch) (3.5.2)
# Requirement already satisfied: torch>=1.1.0 in c:\users\soumy\anaconda3\lib\site-packages (from snntorch) (2.0.1)
# Requirement already satisfied: networkx in c:\users\soumy\anaconda3\lib\site-packages (from torch>=1.1.0->snntorch) (2.8.4)
# Requirement already satisfied: typing-extensions in c:\users\soumy\anaconda3\lib\site-packages (from torch>=1.1.0->snntorch) (4.3.0)
# Requirement already satisfied: filelock in c:\users\soumy\anaconda3\lib\site-packages (from torch>=1.1.0->snntorch) (3.6.0)
# Requirement already satisfied: jinja2 in c:\users\soumy\anaconda3\lib\site-packages (from torch>=1.1.0->snntorch) (3.1.2)
# Requirement already satisfied: sympy in c:\users\soumy\anaconda3\lib\site-packages (from torch>=1.1.0->snntorch) (1.10.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\soumy\anaconda3\lib\site-packages (from matplotlib->snntorch) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\soumy\anaconda3\lib\site-packages (from matplotlib->snntorch) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\soumy\anaconda3\lib\site-packages (from matplotlib->snntorch) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\soumy\anaconda3\lib\site-packages (from matplotlib->snntorch) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\soumy\anaconda3\lib\site-packages (from matplotlib->snntorch) (10.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\soumy\anaconda3\lib\site-packages (from matplotlib->snntorch) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\soumy\anaconda3\lib\site-packages (from matplotlib->snntorch) (3.0.9)
# Requirement already satisfied: h5py in c:\users\soumy\anaconda3\lib\site-packages (from nir->snntorch) (3.7.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\soumy\anaconda3\lib\site-packages (from pandas->snntorch) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\soumy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->snntorch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\soumy\anaconda3\lib\site-packages (from jinja2->torch>=1.1.0->snntorch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\soumy\anaconda3\lib\site-packages (from sympy->torch>=1.1.0->snntorch) (1.2.1)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# Requirement already satisfied: tonic in c:\users\soumy\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: h5py in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (3.7.0)
# Requirement already satisfied: scipy in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (1.7.3)
# Requirement already satisfied: expelliarmus in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (1.1.12)
# Requirement already satisfied: importRosbag>=1.0.4 in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (1.0.4)
# Requirement already satisfied: tqdm in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (4.64.1)
# Requirement already satisfied: librosa in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (0.10.1)
# Requirement already satisfied: typing-extensions in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (4.3.0)
# Requirement already satisfied: numpy in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (1.21.6)
# Requirement already satisfied: pbr in c:\users\soumy\anaconda3\lib\site-packages (from tonic) (6.0.0)
# Requirement already satisfied: setuptools in c:\users\soumy\anaconda3\lib\site-packages (from importRosbag>=1.0.4->tonic) (63.4.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (0.12.1)
# Requirement already satisfied: msgpack>=1.0 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (1.0.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (1.0.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (3.0.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (1.8.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (0.3)
# Requirement already satisfied: numba>=0.51.0 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (0.55.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (0.3.7)
# Requirement already satisfied: joblib>=0.14 in c:\users\soumy\anaconda3\lib\site-packages (from librosa->tonic) (1.1.0)
# Requirement already satisfied: colorama in c:\users\soumy\anaconda3\lib\site-packages (from tqdm->tonic) (0.4.5)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\soumy\anaconda3\lib\site-packages (from numba>=0.51.0->librosa->tonic) (0.38.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\soumy\anaconda3\lib\site-packages (from pooch>=1.0->librosa->tonic) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\soumy\anaconda3\lib\site-packages (from pooch>=1.0->librosa->tonic) (21.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\soumy\anaconda3\lib\site-packages (from pooch>=1.0->librosa->tonic) (2.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\soumy\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa->tonic) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\soumy\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa->tonic) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\soumy\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->tonic) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\soumy\anaconda3\lib\site-packages (from packaging>=20.0->pooch>=1.0->librosa->tonic) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\soumy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->tonic) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\soumy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->tonic) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\soumy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->tonic) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\soumy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->tonic) (2.0.4)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\soumy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\soumy\anaconda3\lib\site-packages)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks/snntorch-LSM')

# %%
import tonic
from tonic import DiskCachedDataset
import tonic.transforms as transforms
import torch
from torch.utils.data import DataLoader

import numpy as np
from sklearn import linear_model
import time

#from lsm_weight_definitions import initWeights1
#from lsm_models import LSM
import lsm_weight_definitions as lsm_wts
import lsm_models

if __name__ == "__main__":

    #Load dataset (Using NMNIST here)
    sensor_size = tonic.datasets.NMNIST.sensor_size
    frame_transform = transforms.Compose([transforms.Denoise(filter_time=3000),
                                          transforms.ToFrame(sensor_size=sensor_size,time_window=1000)])

    trainset = tonic.datasets.NMNIST(save_to='./data', transform=frame_transform, train=True)
    testset = tonic.datasets.NMNIST(save_to='./data', transform=frame_transform, train=False)

    cached_trainset = DiskCachedDataset(trainset, cache_path='./cache/nmnist/train')
    cached_testset = DiskCachedDataset(testset, cache_path='./cache/nmnist/test')

    batch_size = 256
    trainloader = DataLoader(cached_trainset, batch_size=batch_size, collate_fn=tonic.collation.PadTensors(batch_first=False), shuffle=True)
    testloader = DataLoader(cached_testset, batch_size=batch_size, collate_fn=tonic.collation.PadTensors(batch_first=False))

    #Set device
    #device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
    print(device)

    data, targets = next(iter(trainloader))
    flat_data = torch.reshape(data, (data.shape[0], data.shape[1], -1))
    print(flat_data.shape)

    in_sz = flat_data.shape[-1]

    #Set neuron parameters
    tauV = 16.0
    tauI = 16.0
    th = 20
    curr_prefac = np.float32(1/tauI)
    alpha = np.float32(np.exp(-1/tauI))
    beta = np.float32(1 - 1/tauV)

    Win, Wlsm = lsm_wts.initWeights1(27, 2, 0.15, in_sz)
    N = Wlsm.shape[0]
    lsm_net = lsm_models.LSM(N, in_sz, np.float32(curr_prefac*Win), np.float32(curr_prefac*Wlsm), alpha=alpha, beta=beta, th=th).to(device)
    lsm_net.eval()
    #Run with no_grad for LSM
    with torch.no_grad():
        start_time = time.time()
        for i, (data, targets) in enumerate(iter(trainloader)):
            if i%25 == 24:
                print("train batches completed: ", i)
            flat_data = torch.reshape(data, (data.shape[0], data.shape[1], -1)).to(device)
            spk_rec = lsm_net(flat_data)
            lsm_out = torch.mean(spk_rec, dim=0)
            if i==0:
                in_train = torch.mean(flat_data, dim=0).cpu().numpy()
                lsm_out_train = lsm_out.cpu().numpy()
                lsm_label_train = np.int32(targets.numpy())
            else:
                in_train = np.concatenate((in_train, torch.mean(flat_data, dim=0).cpu().numpy()), axis=0)
                lsm_out_train = np.concatenate((lsm_out_train, lsm_out.cpu().numpy()), axis=0)
                lsm_label_train = np.concatenate((lsm_label_train, np.int32(targets.numpy())), axis=0)
        end_time = time.time()

        print("running time of training epoch: ", end_time - start_time, "seconds")

        for i, (data, targets) in enumerate(iter(testloader)):
            if i%25 == 24:
                print("test batches completed: ", i)
            flat_data = torch.reshape(data, (data.shape[0], data.shape[1], -1)).to(device)
            lsm_net.eval()
            spk_rec = lsm_net(flat_data)
            lsm_out = torch.mean(spk_rec, dim=0)
            if i==0:
                in_test = torch.mean(flat_data, dim=0).cpu().numpy()
                lsm_out_test = lsm_out.cpu().numpy()
                lsm_label_test = np.int32(targets.numpy())
            else:
                in_test = np.concatenate((in_test, torch.mean(flat_data, dim=0).cpu().numpy()), axis=0)
                lsm_out_test = np.concatenate((lsm_out_test, lsm_out.cpu().numpy()), axis=0)
                lsm_label_test = np.concatenate((lsm_label_test, np.int32(targets.numpy())), axis=0)

    print(lsm_out_train.shape)
    print(lsm_out_test.shape)

    print(in_train.shape)
    print(in_test.shape)

    print("mean in spiking (train) : ", np.mean(in_train))
    print("mean in spiking (test) : ", np.mean(in_test))

    print("mean LSM spiking (train) : ", np.mean(lsm_out_train))
    print("mean LSM spiking (test) : ", np.mean(lsm_out_test))

    print("training linear model:")
    clf = linear_model.SGDClassifier(max_iter=10000, tol=1e-6)
    clf.fit(lsm_out_train, lsm_label_train)

    score = clf.score(lsm_out_test, lsm_label_test)
    print("test score = " + str(score))
# Out:
# cuda
# torch.Size([310, 256, 2312])
# train batches completed:  24
# train batches completed:  49
# train batches completed:  74
# train batches completed:  99
# train batches completed:  124
# train batches completed:  149
# train batches completed:  174
# train batches completed:  199
# train batches completed:  224
# running time of training epoch:  560.7610261440277 seconds
# test batches completed:  24
# (60000, 1000)
# (10000, 1000)
# (60000, 2312)
# (10000, 2312)
# mean in spiking (train) :  0.0045157326
# mean in spiking (test) :  0.0045442637
# mean LSM spiking (train) :  0.1701422
# mean LSM spiking (test) :  0.17341721
# training linear model:
# test score = 0.9599
